# %% [markdown]
# <a href="https://colab.research.google.com/github/nfrank6-depaul/nlp_transaction_categorization/blob/main/colab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world
